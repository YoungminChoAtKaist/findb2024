# %% [markdown]
# ## Exercise 2-2 : Bank of Korea API

# %%
import requests
import pandas as pd

# %%
BOK_API_URL = 'https://ecos.bok.or.kr/api'
BOK_API_KEY = 'HWA3CTVK03SNSULO3HYB'

# %% [markdown]
# ### 주요국 환율 아이템 목록 조회

# %%
def fetch_bok_data(service_code, stat_code=None):
    url = f"{BOK_API_URL}/{service_code}/{BOK_API_KEY}/json/kr/1/100000"
    
    if stat_code:
        url += f"/{stat_code}"
    
    print(url)
    
    resp = requests.get(url)
    results = resp.json()
    rows = results[service_code]['row']
    df = pd.DataFrame(rows)
    
    return df

# %%
df = fetch_bok_data('StatisticItemList', stat_code='731Y001')
# Out:
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/731Y001

# %%
df
# Out:
#    STAT_CODE               STAT_NAME GRP_CODE GRP_NAME ITEM_CODE  \
# 0    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000001
# 1    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000053
# 2    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000002
# 3    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000003
# 4    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000004
# 5    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000005
# 6    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000006
# 7    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000007
# 8    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000008
# 9    731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000009
# 10   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000010
# 11   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000011
# 12   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000012
# 13   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000013
# 14   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000014
# 15   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000017
# 16   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000026
# 17   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000027
# 18   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000030
# 19   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000015
# 20   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000031
# 21   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000032
# 22   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000033
# 23   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000028
# 24   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000024
# 25   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000029
# 26   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000025
# 27   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000034
# 28   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000035
# 29   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000036
# 30   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000037
# 31   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000038
# 32   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000039
# 33   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000040
# 34   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000041
# 35   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000042
# 36   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000016
# 37   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000018
# 38   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000019
# 39   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000043
# 40   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000044
# 41   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000045
# 42   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000046
# 43   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000020
# 44   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000047
# 45   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000048
# 46   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000049
# 47   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000021
# 48   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000022
# 49   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000023
# 50   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000050
# 51   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000051
# 52   731Y001  3.1.1.1. 주요국 통화의 대원화환율   Group1     계정항목   0000052
#
#              ITEM_NAME P_ITEM_CODE P_ITEM_NAME CYCLE START_TIME  END_TIME  \
# 0        원/미국달러(매매기준율)        None        None     D   19640504  20240809
# 1          원/위안(매매기준율)        None        None     D   20160104  20240809
# 2          원/일본엔(100엔)        None        None     D   19770401  20240809
# 3                 원/유로        None        None     D   19940411  20240809
# 4              원/독일마르크        None        None     D   19640504  20011231
# 5              원/프랑스프랑        None        None     D   19641214  20020216
# 6       원/이태리리라(100리라)        None        None     D   19641214  20020228
# 7              원/벨기에프랑        None        None     D   19700220  20020228
# 8            원/오스트리아실링        None        None     D   19700220  20020228
# 9             원/네덜란드길더        None        None     D   19700220  20020128
# 10    원/스페인페세타(100페세타)        None        None     D   19880104  20020228
# 11            원/핀란드마르카        None        None     D   19880104  20020228
# 12             원/영국파운드        None        None     D   19640504  20240809
# 13             원/캐나다달러        None        None     D   19641214  20240809
# 14             원/스위스프랑        None        None     D   19641214  20240809
# 15              원/호주달러        None        None     D   19700220  20240809
# 16            원/뉴질랜드달러        None        None     D   19880104  20240809
# 17              원/중국위안        None        None     D   19940411  20160201
# 18              원/홍콩위안        None        None     D   20150102  20160308
# 19              원/홍콩달러        None        None     D   19640504  20240809
# 20              원/대만달러        None        None     D   20150102  20240809
# 21             원/몽골투그릭        None        None     D   20150102  20240809
# 22           원/카자흐스탄텡게        None        None     D   20150102  20240809
# 23              원/태국바트        None        None     D   19940411  20240809
# 24            원/싱가포르달러        None        None     D   19830824  20240809
# 25  원/인도네시아루피아(100루피아)        None        None     D   19940411  20240809
# 26           원/말레이지아링깃        None        None     D   19830824  20240809
# 27             원/필리핀페소        None        None     D   20150102  20240809
# 28        원/베트남동(100동)        None        None     D   20150102  20240809
# 29            원/브루나이달러        None        None     D   20150102  20240809
# 30              원/인도루피        None        None     D   20150102  20240809
# 31            원/파키스탄루피        None        None     D   20150102  20240809
# 32           원/방글라데시타카        None        None     D   20150102  20240809
# 33            원/멕시코 페소        None        None     D   20150102  20240809
# 34            원/브라질 헤알        None        None     D   20150102  20240809
# 35           원/아르헨티나페소        None        None     D   20150102  20240809
# 36            원/스웨덴크로나        None        None     D   19670718  20240809
# 37            원/덴마크크로나        None        None     D   19700220  20240809
# 38           원/노르웨이크로나        None        None     D   19700220  20240809
# 39             원/러시아루블        None        None     D   20150102  20240809
# 40            원/헝가리포린트        None        None     D   20150102  20240809
# 41            원/폴란트즈워티        None        None     D   20150102  20240809
# 42             원/체코코루나        None        None     D   20150102  20240809
# 43         원/사우디아라비아리얄        None        None     D   19760701  20240809
# 44             원/카타르리얄        None        None     D   20150102  20240809
# 45            원/이스라엘셰켈        None        None     D   20150102  20240809
# 46            원/요르단디나르        None        None     D   20150102  20240809
# 47           원/쿠웨이트디나르        None        None     D   19770401  20240809
# 48            원/바레인디나르        None        None     D   19770401  20240809
# 49         원/아랍에미리트디르함        None        None     D   19770401  20240809
# 50            원/튀르키예리라        None        None     D   20150102  20240809
# 51        원/남아프리카공화국랜드        None        None     D   20150102  20240809
# 52            원/이집트파운드        None        None     D   20150102  20240809
#
#     DATA_CNT UNIT_NAME WEIGHT
# 0      16998        원    None
# 1       2125        원    None
# 2      13150        원    None
# 3       8112        원    None
# 4      11170        원    None
# 5      10968        원    None
# 6      10980        원    None
# 7       9488        원    None
# 8       9483        원    None
# 9       9464        원    None
# 10      4202        원    None
# 11      4202        원    None
# 12     16985        원    None
# 13     16749        원    None
# 14     16746        원    None
# 15     15250        원    None
# 16      9970        원    None
# 17      6008        원    None
# 18       250        원    None
# 19     16927        원    None
# 20      2374        원    None
# 21      2374        원    None
# 22      2374        원    None
# 23      8112        원    None
# 24     11263        원    None
# 25      8112        원    None
# 26     11263        원    None
# 27      2374        원    None
# 28      2374        원    None
# 29      2374        원    None
# 30      2374        원    None
# 31      2374        원    None
# 32      2374        원    None
# 33      2374        원    None
# 34      2374        원    None
# 35      2374        원    None
# 36     15973        원    None
# 37     15255        원    None
# 38     15257        원    None
# 39      2374        원    None
# 40      2374        원    None
# 41      2374        원    None
# 42      2374        원    None
# 43     13376        원    None
# 44      2374        원    None
# 45      2374        원    None
# 46      2374        원    None
# 47     13151        원    None
# 48     13152        원    None
# 49     13152        원    None
# 50      2374        원    None
# 51      2374        원    None
# 52      2374        원    None

# %% [markdown]
# ### Fetch item values(엔화 환율)

# %%
item = df.loc[2]

# %%
item
# Out:
# STAT_CODE                     731Y001
# STAT_NAME      3.1.1.1. 주요국 통화의 대원화환율
# GRP_CODE                       Group1
# GRP_NAME                         계정항목
# ITEM_CODE                     0000002
# ITEM_NAME                 원/일본엔(100엔)
# P_ITEM_CODE                      None
# P_ITEM_NAME                      None
# CYCLE                               D
# START_TIME                   19770401
# END_TIME                     20240809
# DATA_CNT                        13150
# UNIT_NAME                          원
# WEIGHT                           None
# Name: 2, dtype: object

# %%
def fetch_bok_data(service_code, stat_code=None, item=None):
    url = f"{BOK_API_URL}/{service_code}/{BOK_API_KEY}/json/kr/1/100000"
    
    if item is not None:
        url += "/{}/{}/{}/{}/{}".format(item['STAT_CODE'], item['CYCLE'], item['START_TIME'], item['END_TIME'], item['ITEM_CODE'])
        
    elif stat_code is not None:
        url += f"/{stat_code}"
    
    print(url)
    
    resp = requests.get(url)
    results = resp.json()
    rows = results[service_code]['row']
    df = pd.DataFrame(rows)
    
    return df

# %%
df_xr = fetch_bok_data('StatisticSearch', item=item)
# Out:
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/731Y001/D/19770401/20240809/0000002

# %%
df_xr = df_xr[['TIME', 'DATA_VALUE']]

# %%
df_xr['date'] = pd.to_datetime(df_xr['TIME'])

# %%
df_xr = df_xr.set_index('date')

# %%
del df_xr['TIME']

# %%
df_xr.columns = ['KRW/JPY']

# %%
df_xr['KRW/JPY'] = df_xr['KRW/JPY'].astype(float)

# %%
df_xr
# Out:
#             KRW/JPY
# date
# 1977-04-01   174.50
# 1977-04-02   174.50
# 1977-04-04   174.50
# 1977-04-06   177.40
# 1977-04-07   177.23
# ...             ...
# 2024-08-05   938.67
# 2024-08-06   937.18
# 2024-08-07   949.49
# 2024-08-08   940.13
# 2024-08-09   934.32
#
# [13150 rows x 1 columns]

# %%
df_xr.to_excel('data/krw_jpy_xr.xlsx')

# %% [markdown]
# # Exercise 3-1

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (10,4)

# %%
plt.plot(df_xr['KRW/JPY'])
plt.show()

# %% [markdown]
# ### Convert to monthly observations
# #### End-of-month observation

# %%
df_monthly = df_xr.resample('M').last()

# %%
df_monthly['ret'] = df_monthly['KRW/JPY'].pct_change() * 100

# %%
df_monthly.head(3)
# Out:
#             KRW/JPY       ret
# date
# 1977-04-30   174.28       NaN
# 1977-05-31   174.67  0.223778
# 1977-06-30   180.11  3.114444

# %% [markdown]
# ### 환율 변화율을 예측하기

# %%
import statsmodels.api as sm

# %%
df_monthly = df_monthly.dropna()

# %% [markdown]
# * IMF 이전 환율정책:
#
# IMF 외환위기 이전 한국은 '관리변동환율제'를 채택하고 있었습니다.
# 이 제도 하에서 정부는 환율의 일일 변동폭을 제한하고, 외환시장에 직접 개입하여 환율을 관리했습니다.
#
#
# * IMF 이후 환율정책:
#
# 1997년 12월 IMF 구제금융을 받으면서 한국은 '자유변동환율제'로 전환했습니다.
# 이 제도에서는 원칙적으로 시장의 수요와 공급에 따라 환율이 결정됩니다.
# 정부의 직접적인 시장 개입은 크게 줄어들었습니다

# %% [markdown]
# * 아베노믹스 (2012년~): 2012년 12월 26일
#
# 영향력: 매우 큼
# 지속기간: 장기적 (수년간 지속)
# 직접성: 엔화 환율에 직접적인 영향
# 의도성: 의도적인 엔화 약세 정책
#
# 아베노믹스는 일본 경제 회복을 위해 의도적으로 엔화 가치를 낮추는 정책을 포함했습니다. 이로 인해 엔화 가치가 급격히 하락했고, 원/엔 환율에 지속적이고 큰 영향을 미쳤습니다.

# %%
df_post_abe = df_monthly.loc['2012-12-26':]

# %%
X = df_post_abe.iloc[:-1]['ret']
X = sm.add_constant(X)

# %%
Y = df_post_abe.iloc[1:]['ret']

# %%
model = sm.OLS(Y, X.values)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ret   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                   0.02576
# Date:                Sat, 10 Aug 2024   Prob (F-statistic):              0.873
# Time:                        12:37:12   Log-Likelihood:                -323.52
# No. Observations:                 140   AIC:                             651.0
# Df Residuals:                     138   BIC:                             656.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1733      0.209     -0.830      0.408      -0.586       0.239
# x1             0.0135      0.084      0.160      0.873      -0.153       0.180
# ==============================================================================
# Omnibus:                        0.600   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.741   Jarque-Bera (JB):                0.595
# Skew:                           0.154   Prob(JB):                        0.743
# Kurtosis:                       2.913   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Exercise 4-1

# %%
df_monthly = df_monthly.loc['2012-12-26':]

# %%
plt.rcParams['figure.figsize'] = (10,4)
plt.plot(df_post_abe['KRW/JPY'])
plt.show()

# %%
df_real_xr = pd.read_excel('data\world_real_xr.xls', sheet_name='Data', skiprows=3)

# %%
df_real_xr = df_real_xr.set_index('Country Code')

# %%
from pandas.tseries.offsets import YearEnd, MonthEnd

# %%
df_real_xr_kor = df_real_xr.loc['KOR'].to_frame()
df_real_xr_kor = df_real_xr_kor.iloc[3:]
df_real_xr_kor = df_real_xr_kor.dropna()
df_real_xr_kor['KOR'] = df_real_xr_kor['KOR'].astype(float)
df_real_xr_kor['date'] = pd.to_datetime(df_real_xr_kor.index) + YearEnd()
df_real_xr_kor = df_real_xr_kor.set_index('date')
df_real_xr_kor.columns = ['KOR Real XR']
df_real_xr_kor.head()
# Out:
#             KOR Real XR
# date
# 1990-12-31     0.791111
# 1991-12-31     0.806041
# 1992-12-31     0.797916
# 1993-12-31     0.805471
# 1994-12-31     0.852152

# %%
df_real_xr_jpn = df_real_xr.loc['JPN'].to_frame()
df_real_xr_jpn = df_real_xr_jpn.iloc[3:]
df_real_xr_jpn = df_real_xr_jpn.dropna()
df_real_xr_jpn['JPN'] = df_real_xr_jpn['JPN'].astype(float)
df_real_xr_jpn['date'] = pd.to_datetime(df_real_xr_jpn.index) + YearEnd()
df_real_xr_jpn = df_real_xr_jpn.set_index('date')
df_real_xr_jpn.columns = ['JPN Real XR']
df_real_xr_jpn.head()
# Out:
#             JPN Real XR
# date
# 1990-12-31     1.295738
# 1991-12-31     1.386324
# 1992-12-31     1.465824
# 1993-12-31     1.639495
# 1994-12-31     1.749671

# %%
# 기존의 KOR와 JPN 데이터프레임을 합칩니다
df_combined = pd.concat([df_real_xr_kor, df_real_xr_jpn], axis=1)

# KRW/100JPY 실질환율 계산
# KRW/USD를 JPY/USD로 나누고 100을 곱합니다 (100엔 기준으로 변환)
df_combined['KRW/100JPY Real XR'] = df_combined['KOR Real XR'] / (df_combined['JPN Real XR'] * 100)

# 결과 확인
print(df_combined.tail())
# Out:
#             KOR Real XR  JPN Real XR  KRW/100JPY Real XR
# date
# 2019-12-31     0.727286     0.946994            0.007680
# 2020-12-31     0.702688     0.943502            0.007448
# 2021-12-31     0.723172     0.899195            0.008042
# 2022-12-31     0.627537     0.721953            0.008692
# 2023-12-31     0.612982     0.673903            0.009096

# %%
df_real_xr = df_combined['KRW/100JPY Real XR']

# %%
plt.plot(df_real_xr)
plt.show()

# %% [markdown]
# ## Overlapping monthly forecasts

# %%
df_monthly = df_monthly.drop('ret', axis=1)

# %%
df_merged = df_monthly.join(df_real_xr)

# %%
# ffill - forward fill
# bfill - backward fill
df_merged['KRW/100JPY Real XR'] = df_merged['KRW/100JPY Real XR'].fillna(method='ffill')

# %%
df_merged['ann_ret'] = df_merged['KRW/JPY'].pct_change(periods=12) * 100

# %%
df_merged['F12.ann_ret'] = df_merged['ann_ret'].shift(-12)

# %%
df_merged.head(15)
# Out:
#             KRW/JPY  KRW/100JPY Real XR    ann_ret  F12.ann_ret
# date
# 2012-12-31  1247.50            0.005805        NaN   -19.466132
# 2013-01-31  1188.47            0.005805        NaN   -12.180366
# 2013-02-28  1176.20            0.005805        NaN   -11.169869
# 2013-03-31  1180.13            0.005805        NaN   -11.981731
# 2013-04-30  1132.04            0.005805        NaN   -11.194834
# 2013-05-31  1116.58            0.005805        NaN   -10.066453
# 2013-06-30  1167.15            0.005805        NaN   -14.321210
# 2013-07-31  1135.40            0.005805        NaN   -12.302272
# 2013-08-31  1129.19            0.005805        NaN   -13.426438
# 2013-09-30  1098.67            0.005805        NaN   -12.599780
# 2013-10-31  1077.51            0.005805        NaN   -10.529833
# 2013-11-30  1038.17            0.005805        NaN   -10.048451
# 2013-12-31  1004.66            0.007647 -19.466132    -8.412796
# 2014-01-31  1043.71            0.007647 -12.180366   -11.722605
# 2014-02-28  1044.82            0.007647 -11.169869   -11.877644

# %% [markdown]
# ### Use OLS to fit the forecast model

# %%
df = df_merged[['KRW/100JPY Real XR', 'F12.ann_ret']]
df = df.dropna()

# %%
X = df['KRW/100JPY Real XR']
X = sm.add_constant(X)
Y = df['F12.ann_ret']

# %%
model = sm.OLS(Y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            F12.ann_ret   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     42.52
# Date:                Sat, 10 Aug 2024   Prob (F-statistic):           1.50e-09
# Time:                        12:37:13   Log-Likelihood:                -436.42
# No. Observations:                 129   AIC:                             876.8
# Df Residuals:                     127   BIC:                             882.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                -42.7031      6.292     -6.787      0.000     -55.153     -30.253
# KRW/100JPY Real XR  5184.8916    795.179      6.520      0.000    3611.376    6758.407
# ==============================================================================
# Omnibus:                        5.103   Durbin-Watson:                   0.236
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                4.894
# Skew:                           0.477   Prob(JB):                       0.0866
# Kurtosis:                       3.044   Cond. No.                     1.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Exercise 4-2
# ## Real XR 대신 PPP XR 활용하기

# %%
def load_world_bank_data(filepath, country, column):
    df = pd.read_excel(filepath, sheet_name='Data', skiprows=3)

    df = df.set_index('Country Code')
    df = df.loc[country].to_frame()
    df = df.iloc[3:]
    df = df.dropna()
    df = df.astype(float)
    
    df['date'] = pd.to_datetime(df.index) + YearEnd()
    df = df.set_index('date')
    df.columns = [column]
    
    return df

# %%
df_ppp_xr_kor = load_world_bank_data('data\world_ppp_xr.xls', 'KOR', 'PPP XR')

# %%
df_ppp_xr_jpn = load_world_bank_data('data\world_ppp_xr.xls', 'JPN', 'PPP XR')

# %%
df_ppp_combined = pd.concat([df_ppp_xr_kor, df_ppp_xr_jpn], axis=1)
df_ppp_combined.columns = ['KOR PPP XR', 'JPN PPP XR']
df_ppp_combined['KRW/100JPY PPP XR'] = df_ppp_combined['KOR PPP XR'] / (df_ppp_combined['JPN PPP XR'] * 100)
df_ppp_xr = df_ppp_combined.drop(['KOR PPP XR', 'JPN PPP XR'], axis=1)

# %%
df_ppp_xr.head(3)
# Out:
#             KRW/100JPY PPP XR
# date
# 1990-12-31           0.029844
# 1991-12-31           0.031653
# 1992-12-31           0.033552

# %% [markdown]
# ### Merge with monthly observations

# %%
df_merged = df_monthly.join(df_real_xr)

# %%
df_merged = df_merged.join(df_ppp_xr)

# %%
df_merged.head(3)
# Out:
#             KRW/JPY  KRW/100JPY Real XR  KRW/100JPY PPP XR
# date
# 2012-12-31  1247.50            0.005805           0.081985
# 2013-01-31  1188.47                 NaN                NaN
# 2013-02-28  1176.20                 NaN                NaN

# %% [markdown]
# ### Compute Real XR

# %%
df_merged['KRW/100JPY PPP XR'] = df_merged['KRW/100JPY PPP XR'].ffill()

# %%
df_merged.head(3)
# Out:
#             KRW/JPY  KRW/100JPY Real XR  KRW/100JPY PPP XR
# date
# 2012-12-31  1247.50            0.005805           0.081985
# 2013-01-31  1188.47                 NaN           0.081985
# 2013-02-28  1176.20                 NaN           0.081985

# %%
df_merged['New Real XR'] = df_merged['KRW/100JPY PPP XR'] / df_merged['KRW/JPY'] *100

# %%
df_merged.tail()
# Out:
#             KRW/JPY  KRW/100JPY Real XR  KRW/100JPY PPP XR  New Real XR
# date
# 2024-04-30   882.68                 NaN           0.084534     0.009577
# 2024-05-31   877.84                 NaN           0.084534     0.009630
# 2024-06-30   864.31                 NaN           0.084534     0.009781
# 2024-07-31   905.44                 NaN           0.084534     0.009336
# 2024-08-31   934.32                 NaN           0.084534     0.009048

# %%
df_merged['KRW/100JPY Real XR'] = df_merged['KRW/100JPY Real XR'].ffill()

# %%
plt.plot(df_merged['New Real XR'], label='New Real XR')
plt.plot(df_merged['KRW/100JPY Real XR'].shift(-12), label='World Bank')
plt.legend()
plt.show()

# %% [markdown]
# # KRW/100JPY Real XR 다시확인해보기

# %% [markdown]
# ## Compute annual XR return

# %%
df_merged['ann_ret'] = df_merged['KRW/JPY'].pct_change(periods=12)*100

# %%
df_merged['F12.ann_ret'] = df_merged['ann_ret'].shift(-12)

# %%
df_merged.head(5)
# Out:
#             KRW/JPY  KRW/100JPY Real XR  KRW/100JPY PPP XR  New Real XR  \
# date
# 2012-12-31  1247.50            0.005805           0.081985     0.006572
# 2013-01-31  1188.47            0.005805           0.081985     0.006898
# 2013-02-28  1176.20            0.005805           0.081985     0.006970
# 2013-03-31  1180.13            0.005805           0.081985     0.006947
# 2013-04-30  1132.04            0.005805           0.081985     0.007242
#
#             ann_ret  F12.ann_ret
# date
# 2012-12-31      NaN   -19.466132
# 2013-01-31      NaN   -12.180366
# 2013-02-28      NaN   -11.169869
# 2013-03-31      NaN   -11.981731
# 2013-04-30      NaN   -11.194834

# %% [markdown]
# ### Use OLS to fit the forecast model

# %%
df = df_merged[['New Real XR', 'F12.ann_ret']]
df = df.dropna()

# %%
X = df['New Real XR']
X = sm.add_constant(X)
Y = df['F12.ann_ret']

# %%
model = sm.OLS(Y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            F12.ann_ret   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.289
# Method:                 Least Squares   F-statistic:                     52.98
# Date:                Sat, 10 Aug 2024   Prob (F-statistic):           3.10e-11
# Time:                        12:37:13   Log-Likelihood:                -432.56
# No. Observations:                 129   AIC:                             869.1
# Df Residuals:                     127   BIC:                             874.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -59.1016      7.884     -7.496      0.000     -74.703     -43.500
# New Real XR  7032.6267    966.148      7.279      0.000    5120.793    8944.460
# ==============================================================================
# Omnibus:                        4.320   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.115   Jarque-Bera (JB):                3.365
# Skew:                           0.273   Prob(JB):                        0.186
# Kurtosis:                       2.428   Cond. No.                     1.57e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Predict XR

# %%
last_obs = df_merged.iloc[-1]

# %%
last_obs
# Out:
# KRW/JPY               934.320000
# KRW/100JPY Real XR      0.009096
# KRW/100JPY PPP XR       0.084534
# New Real XR             0.009048
# ann_ret                 3.231794
# F12.ann_ret                  NaN
# Name: 2024-08-31 00:00:00, dtype: float64

# %%
last_xr = last_obs['KRW/JPY']
last_real_xr = last_obs['New Real XR']

# %%
last_xr
# Out:
# 934.32

# %%
last_real_xr
# Out:
# 0.009047673662483777

# %% [markdown]
# ### OLS 결과 그대로 사용하여 예측

# %%
#exogeneous variables
exog = [1, last_real_xr]
results.predict(exog=exog)
# Out:
# array([4.52728093])

# %% [markdown]
# ### Confidence Interval

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
for alpha in [0.05, 0.25, 0.50]:
    prstd, iv_l, iv_u = wls_prediction_std(results, exog=exog, alpha=alpha)
    
    print('Confidence interval at alpha = {:.2f}: {:.2f} ~ {:.2f}'.format(
        alpha,
        iv_l[0],
        iv_u[0],
    ))
# Out:
# Confidence interval at alpha = 0.05: -9.43 ~ 18.49
# Confidence interval at alpha = 0.25: -3.63 ~ 12.68
# Confidence interval at alpha = 0.50: -0.25 ~ 9.30

# %% [markdown]
# ### 환율 예측하기

# %%
pred_ret = results.predict(exog=exog)
last_xr * (1 + pred_ret[0]/100)
# Out:
# 976.6192911547109

# %%
for alpha in [0.05, 0.25, 0.50]:
    prstd, iv_l, iv_u = wls_prediction_std(results, exog=exog, alpha=alpha)
    
    print('Confidence interval at alpha = {:.2f}: {:.2f} ~ {:.2f}'.format(
        alpha,
        last_xr * (1 + iv_l[0] / 100),
        last_xr * (1 + iv_u[0] / 100),
    ))
# Out:
# Confidence interval at alpha = 0.05: 846.18 ~ 1107.06
# Confidence interval at alpha = 0.25: 900.44 ~ 1052.80
# Confidence interval at alpha = 0.50: 932.03 ~ 1021.21

# %% [markdown]
# # Exercise 5(지표 모으기)

# %%
def fetch_bok_data(service_code, stat_code=None, item=None):
    url = f"{BOK_API_URL}/{service_code}/{BOK_API_KEY}/json/kr/1/100000"
    
    if item is not None:
        url += "/{}/{}/{}/{}/{}".format(item['STAT_CODE'], item['CYCLE'], item['START_TIME'], item['END_TIME'], item['ITEM_CODE'])
        
        if type(item['ITEM_CODE2']) is str:
            url += f"/{item['ITEM_CODE2']}"
        
    elif stat_code is not None:
        url += f"/{stat_code}"
    
    print(url)
    
    resp = requests.get(url)
    results = resp.json()
    rows = results[service_code]['row']
    df = pd.DataFrame(rows)
    
    return df

# %%
TARGET_STAT_CODES = [
    '731Y001',  # 3.1.1.1. 주요국 통화의 대원화환율
    '902Y008',  # 9.1.2.2. 국제 주요국 소비자물가지수
    '902Y009',  # 9.1.3.1. 국제 주요국 경상수지
    '902Y015',  # 9.1.4.1. 국제 주요국 경제성장률
    '902Y016',  # 9.1.4.2. 국제 주요국 국내총생산(GDP)
    '902Y023',  # 9.1.6.1. 주요국제금리
    '817Y002',  # 1.3.2.1. 시장금리(일별)
    '732Y001',  # 3.5. 외환보유액
]

# %%
dfs = []

for stat_code in TARGET_STAT_CODES:
    df = fetch_bok_data('StatisticItemList', stat_code=stat_code)
    
    dfs.append(df)
# Out:
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/731Y001
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y008
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y009
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y015
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y016
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y023
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/817Y002
# https://ecos.bok.or.kr/api/StatisticItemList/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/732Y001

# %%
df_item_codes = pd.concat(dfs, axis=0)

# %%
df_item_codes.to_excel('data\\bok_item_codes.xlsx', index=False)

# %%
df_item_codes = df_item_codes.set_index(['STAT_CODE', 'ITEM_CODE', 'CYCLE'])

# %% [markdown]
# ### Download data values

# %%
data_download_list = pd.read_excel('data\\bok_data_download_list_jpy.xlsx')

# %%
data_download_list
# Out:
#                      name STAT_CODE                   STAT_NAME ITEM_CODE  \
# 0           krw_100jpy_xr   731Y001      3.1.1.1. 주요국 통화의 대원화환율   0000002
# 1               cpi_korea   902Y008     9.1.2.2. 국제 주요국 소비자물가지수        KR
# 2                  cpi_jp   902Y008     9.1.2.2. 국제 주요국 소비자물가지수        JP
# 3                  cpi_us   902Y008     9.1.2.2. 국제 주요국 소비자물가지수        US
# 4   current_account_korea   902Y009        9.1.3.1. 국제 주요국 경상수지        KR
# 5      current_account_jp   902Y009        9.1.3.1. 국제 주요국 경상수지        JP
# 6      current_account_us   902Y009        9.1.3.1. 국제 주요국 경상수지        US
# 7        gdp_growth_korea   902Y015       9.1.4.1. 국제 주요국 경제성장률       KOR
# 8           gdp_growth_jp   902Y015       9.1.4.1. 국제 주요국 경제성장률       JPN
# 9           gdp_growth_us   902Y015       9.1.4.1. 국제 주요국 경제성장률       USA
# 10              gdp_korea   902Y016  9.1.4.2. 국제 주요국 국내총생산(GDP)       KOR
# 11                 gdp_jp   902Y016  9.1.4.2. 국제 주요국 국내총생산(GDP)       JPN
# 12                 gdp_us   902Y016  9.1.4.2. 국제 주요국 국내총생산(GDP)       USA
# 13       foreign_reserves   732Y001                  3.5. 외환보유액        99
# 14         int_rate_korea   902Y023             9.1.6.1. 주요국제금리    IR3TIB
# 15            int_rate_jp   902Y023             9.1.6.1. 주요국제금리    IR3TIB
# 16            int_rate_us   902Y023             9.1.6.1. 주요국제금리    IR3TIB
#
#    ITEM_CODE2    ITEM_NAME CYCLE UNIT_NAME
# 0         NaN  원/일본엔(100엔)     D        원
# 1         NaN           한국     M  2010=100
# 2         NaN           일본     M  2010=100
# 3         NaN           미국     M  2010=100
# 4         NaN           한국     Q      백만달러
# 5         NaN           일본     Q      백만달러
# 6         NaN           미국     Q      백만달러
# 7         NaN           한국     Q        %
# 8         NaN           일본     Q        %
# 9         NaN           미국     Q        %
# 10        NaN           한국     A      백만달러
# 11        NaN           일본     A      백만달러
# 12        NaN           미국     A      백만달러
# 13        NaN           합계     M      천달러
# 14        KOR    단기금리 - 한국     M        %
# 15        USA    단기금리 - 일본     M        %
# 16        JPN    단기금리 - 미국     M        %

# %%
#iterate over row
for idx, row in data_download_list.iterrows():
    name = row['name']
    print(f"Downloading {name}...")
    
    idx = (row.STAT_CODE, row.ITEM_CODE, row.CYCLE)
    item = df_item_codes.loc[idx]
    item ={**item, **row}
    
    df = fetch_bok_data('StatisticSearch', item=item)
    df = df[['TIME', 'DATA_VALUE']]
    
    if row['CYCLE'] == 'D':
        df['date'] = pd.to_datetime(df['TIME'])
    
    elif row['CYCLE'] == 'M':
        df['date'] = pd.to_datetime(df['TIME'], format='%Y%m') + MonthEnd()
    
    elif row['CYCLE'] == 'Q':
        df['year'] = df['TIME'].str[:4]
        df['month'] = df['TIME'].str[-1].astype(int) * 3
        df['day'] = 1
        df['date'] = pd.to_datetime(df[['year', 'month', 'day']]) + MonthEnd()
    
    elif row['CYCLE'] == 'A':
        df['date'] = pd.to_datetime(df['TIME']) + YearEnd()
    
    else:
        raise RuntimeError()
        
    df = df[['date','DATA_VALUE']]
    df = df.rename(columns={'DATA_VALUE': name, })
    
    df[name] = df[name].astype(float)
    
    df.to_excel(f"data\{name}.xlsx", index=False)
    
print('** Completed!! **')
# Out:
# Downloading krw_100jpy_xr...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/731Y001/D/19770401/20240809/0000002
# Downloading cpi_korea...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y008/M/195108/202406/KR
# Downloading cpi_jp...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y008/M/195501/202406/JP
# Downloading cpi_us...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y008/M/195501/202406/US
# Downloading current_account_korea...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y009/Q/1976Q1/2024Q1/KR
# Downloading current_account_jp...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y009/Q/1996Q1/2024Q1/JP
# Downloading current_account_us...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y009/Q/1973Q1/2024Q1/US
# Downloading gdp_growth_korea...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y015/Q/1960Q2/2024Q2/KOR
# Downloading gdp_growth_jp...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y015/Q/1960Q2/2024Q1/JPN
# Downloading gdp_growth_us...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y015/Q/1947Q2/2024Q2/USA
# Downloading gdp_korea...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y016/A/1953/2023/KOR
# Downloading gdp_jp...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y016/A/1970/2023/JPN
# Downloading gdp_us...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y016/A/1970/2023/USA
# Downloading foreign_reserves...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/732Y001/M/197101/202407/99
# Downloading int_rate_korea...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y023/M/195601/202406/IR3TIB/KOR
# Downloading int_rate_jp...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y023/M/195601/202406/IR3TIB/USA
# Downloading int_rate_us...
# https://ecos.bok.or.kr/api/StatisticSearch/HWA3CTVK03SNSULO3HYB/json/kr/1/100000/902Y023/M/195601/202406/IR3TIB/JPN
# ** Completed!! **

# %% [markdown]
# ### bok데이터 불러오기

# %%
filenames = [
    'krw_jpy_xr',
    'current_account_korea',
    'current_account_us',
    'current_account_jp',
    'gdp_korea',
    'gdp_us',
    'gdp_jp',
    'gdp_growth_korea',
    'gdp_growth_jp',
    'gdp_growth_us',
    'cpi_korea',
    'cpi_jp',
    'cpi_us',
    'int_rate_korea',
    'int_rate_jp',
    'int_rate_us',
    'foreign_reserves',
]

# %%
dfs = []

for fname in filenames:
    print(f"Loding {fname}....")
    
    df = pd.read_excel(f"data\\{fname}.xlsx")
    df = df.set_index('date')
    
    if fname in ['gdp_growth_korea',
        'gdp_growth_jp',
        'gdp_growth_us',
        'current_account_us',
        'current_account_jp',
        'current_account_korea',
                ]:
        df[fname] = df[fname].rolling(4).sum()
    
    dfs.append(df)
    
print('** Completed **')
# Out:
# Loding krw_jpy_xr....
# Loding current_account_korea....
# Loding current_account_us....
# Loding current_account_jp....
# Loding gdp_korea....
# Loding gdp_us....
# Loding gdp_jp....
# Loding gdp_growth_korea....
# Loding gdp_growth_jp....
# Loding gdp_growth_us....
# Loding cpi_korea....
# Loding cpi_jp....
# Loding cpi_us....
# Loding int_rate_korea....
# Loding int_rate_jp....
# Loding int_rate_us....
# Loding foreign_reserves....
# ** Completed **

# %% [markdown]
# ### World Bank 데이터로 계산했었던 KOR/100JPY PPP XR 불러오기

# %%
dfs.append(df_ppp_xr)

# %% [markdown]
# ### Merge the datases

# %%
df_merged = pd.concat(dfs, axis=1)
df_merged = df_merged.resample('M').last()
df_merged = df_merged.ffill()
df_merged.loc['2010-01-01':].head()
# Out:
#             KRW/JPY  current_account_korea  current_account_us  \
# date
# 2010-01-31  1287.00                33087.6           -379736.0
# 2010-02-28  1299.31                33087.6           -379736.0
# 2010-03-31  1217.68                20931.1           -382885.0
# 2010-04-30  1186.77                20931.1           -382885.0
# 2010-05-31  1318.54                20931.1           -382885.0
#
#             current_account_jp  gdp_korea      gdp_us     gdp_jp  \
# date
# 2010-01-31           145677.71   943708.5  14478067.0  5289493.7
# 2010-02-28           145677.71   943708.5  14478067.0  5289493.7
# 2010-03-31           181383.81   943708.5  14478067.0  5289493.7
# 2010-04-30           181383.81   943708.5  14478067.0  5289493.7
# 2010-05-31           181383.81   943708.5  14478067.0  5289493.7
#
#             gdp_growth_korea  gdp_growth_jp  gdp_growth_us  cpi_korea  cpi_jp  \
# date
# 2010-01-31             5.399         -1.661          0.118      98.82  100.09
# 2010-02-28             5.399         -1.661          0.118      99.02  100.09
# 2010-03-31             7.478          4.205          1.738      99.22  100.30
# 2010-04-30             7.478          4.205          1.738      99.62  100.30
# 2010-05-31             7.478          4.205          1.738      99.72  100.30
#
#             cpi_us  int_rate_korea  int_rate_jp  int_rate_us  \
# date
# 2010-01-31   99.37            2.88         0.20         0.45
# 2010-02-28   99.40            2.88         0.19         0.44
# 2010-03-31   99.81            2.83         0.23         0.43
# 2010-04-30   99.98            2.51         0.30         0.40
# 2010-05-31  100.06            2.45         0.45         0.39
#
#             foreign_reserves  KRW/100JPY PPP XR
# date
# 2010-01-31       273693584.0             0.0719
# 2010-02-28       270659721.0             0.0719
# 2010-03-31       272331061.0             0.0719
# 2010-04-30       278873477.0             0.0719
# 2010-05-31       270221038.0             0.0719

# %% [markdown]
# # >>반영할 수 있는 지표들

# %% [markdown]
# ### 환율 수익률

# %%
df_merged['ann_ret'] = df_merged['KRW/JPY'].pct_change(periods=12) * 100
df_merged['F12.ann_ret'] = df_merged['ann_ret'].shift(-12)

# %% [markdown]
# ### Real XR

# %%
df_merged['real_xr'] = df_merged['KRW/100JPY PPP XR'] / df_merged['KRW/JPY']

# %% [markdown]
# ### Current accounts(경상수지) relative to GDP

# %%
df_merged['ca_gdp_korea'] = df_merged['current_account_korea'] / df_merged['gdp_korea'] * 100
df_merged['ca_gdp_jp'] = df_merged['current_account_jp'] / df_merged['gdp_jp'] * 100

# %%
df_merged.loc['2012-12-26':][['ca_gdp_korea', 'ca_gdp_jp']].head()
# Out:
#             ca_gdp_korea  ca_gdp_jp
# date
# 2012-12-31      3.817592   0.958443
# 2013-01-31      3.817592   0.958443
# 2013-02-28      3.817592   0.958443
# 2013-03-31      4.834542   0.809522
# 2013-04-30      4.834542   0.809522

# %%
#stationary process

plt.plot(df_merged['ca_gdp_korea'])
plt.plot(df_merged['ca_gdp_jp'])
plt.show()

# %% [markdown]
# ### GDP Growth

# %%
df_merged['gdp_growth_korea2'] = df_merged['gdp_korea'].pct_change(periods=12) * 100
df_merged['gdp_growth_jp2'] = df_merged['gdp_jp'].pct_change(periods=12) * 100

# %%
df_merged.loc[['2018-12-31', '2019-12-31']][['gdp_jp', 'gdp_growth_jp', 'gdp_growth_jp2']]
# Out:
#                gdp_jp  gdp_growth_jp  gdp_growth_jp2
# date
# 2018-12-31  5040880.9         -0.271        2.231741
# 2019-12-31  5117993.9         -2.006        1.529752

# %% [markdown]
# ### Inflation (YoY, Y/Y)

# %%
df_merged['infl_korea'] = df_merged['cpi_korea'].pct_change(periods=12) * 100
df_merged['infl_jp'] = df_merged['cpi_jp'].pct_change(periods=12) * 100

# %% [markdown]
# ### 상대적 인플레이션 & 금리 차이

# %%
df_merged['infl_diff'] = df_merged['infl_korea'] - df_merged['infl_jp']
df_merged['int_rate_diff'] = df_merged['int_rate_korea'] - df_merged['int_rate_jp']

# %% [markdown]
# ### GDP 대비 외환보유액 및 증가율

# %%
df_merged['reserves_to_gdp'] = df_merged['foreign_reserves'] / df_merged['gdp_korea'] /1000 * 100

# %%
df_merged['reserves_growth'] = df_merged['foreign_reserves'].pct_change(periods=12) * 100

# %% [markdown]
# ### 필요한 컬럼만 남김

# %%
df_sample = df_merged[[
    'F12.ann_ret', 'real_xr',
    'ca_gdp_korea', 'ca_gdp_jp',
    'gdp_growth_korea', 'gdp_growth_jp',
    'infl_diff', 'int_rate_diff',
    'reserves_to_gdp', 'reserves_growth'
]]

# %%
df_sample = df_sample.dropna()

# %%
df_sample = df_sample.loc['1998-12-31':]

# %%
import seaborn as sns

# %%
df_sample.head()
# Out:
#             F12.ann_ret   real_xr  ca_gdp_korea  ca_gdp_jp  gdp_growth_korea  \
# date
# 1998-12-31     6.489981  0.000044     10.477291   2.798314            -3.383
# 1999-01-31     3.873215  0.000046     10.477291   2.798314            -3.383
# 1999-02-28     0.651967  0.000045     10.477291   2.798314            -3.383
# 1999-03-31     3.053360  0.000046      8.936132   2.731757             6.470
# 1999-04-30     4.126127  0.000047      8.936132   2.731757             6.470
#
#             gdp_growth_jp  infl_diff  int_rate_diff  reserves_to_gdp  \
# date
# 1998-12-31         -0.676   3.367014           2.56        13.592840
# 1999-01-31         -0.676   1.269399           2.11        13.999523
# 1999-02-28         -0.676   0.265566           1.80        14.485070
# 1999-03-31         -0.827   0.912194           1.65        15.005900
# 1999-04-30         -0.827   0.526887           1.28        15.479473
#
#             reserves_growth
# date
# 1998-12-31       155.033859
# 1999-01-31       127.925687
# 1999-02-28       107.584787
# 1999-03-31        93.118709
# 1999-04-30        66.733513

# %%
import seaborn as sns

# %%
corr = df_sample.corr()

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
import numpy as np

# %%
# triu = upper triangle
mask = np.triu(np.ones_like(corr))

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# %%
sns.heatmap(corr, cmap=cmap, mask=mask, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
df_sample = df_sample.dropna()

# %%
df_sample2 = df_sample[[
    'real_xr',
    'ca_gdp_korea', 'ca_gdp_jp',
    'gdp_growth_korea', 'gdp_growth_jp',
    'infl_diff', 'int_rate_diff',
    'reserves_to_gdp', 'reserves_growth'
]]

# %%
X = df_sample2
X = sm.add_constant(X)
Y = df_sample['F12.ann_ret']

# %%
df_sample
# Out:
#             F12.ann_ret   real_xr  ca_gdp_korea  ca_gdp_jp  gdp_growth_korea  \
# date
# 1998-12-31     6.489981  0.000044     10.477291   2.798314            -3.383
# 1999-01-31     3.873215  0.000046     10.477291   2.798314            -3.383
# 1999-02-28     0.651967  0.000045     10.477291   2.798314            -3.383
# 1999-03-31     3.053360  0.000046      8.936132   2.731757             6.470
# 1999-04-30     4.126127  0.000047      8.936132   2.731757             6.470
# ...                 ...       ...           ...        ...               ...
# 2023-04-30   -11.787574  0.000085      0.352616   1.579321             1.176
# 2023-05-31    -7.203112  0.000090      0.352616   1.579321             1.176
# 2023-06-30    -4.703573  0.000094      0.149446   2.093027             0.929
# 2023-07-31    -0.312679  0.000094      0.149446   2.093027             0.929
# 2023-08-31     3.231794  0.000094      0.149446   2.093027             0.929
#
#             gdp_growth_jp  infl_diff  int_rate_diff  reserves_to_gdp  \
# date
# 1998-12-31         -0.676   3.367014           2.56        13.592840
# 1999-01-31         -0.676   1.269399           2.11        13.999523
# 1999-02-28         -0.676   0.265566           1.80        14.485070
# 1999-03-31         -0.827   0.912194           1.65        15.005900
# 1999-04-30         -0.827   0.526887           1.28        15.479473
# ...                   ...        ...            ...              ...
# 2023-04-30          2.433   0.145276          -1.53        25.490139
# 2023-05-31          2.433   0.133449          -1.51        25.149604
# 2023-06-30          2.204  -0.604380          -1.47        25.177715
# 2023-07-31          2.204  -0.968073          -1.60        25.198617
# 2023-08-31          2.204   0.234659          -1.74        24.989364
#
#             reserves_growth
# date
# 1998-12-31       155.033859
# 1999-01-31       127.925687
# 1999-02-28       107.584787
# 1999-03-31        93.118709
# 1999-04-30        66.733513
# ...                     ...
# 2023-04-30        -5.033205
# 2023-05-31        -5.969863
# 2023-06-30        -3.838753
# 2023-07-31        -3.830678
# 2023-08-31        -4.154381
#
# [297 rows x 10 columns]

# %%
model = sm.OLS(Y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            F12.ann_ret   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     40.22
# Date:                Sat, 10 Aug 2024   Prob (F-statistic):           9.59e-43
# Time:                        12:43:37   Log-Likelihood:                -1107.9
# No. Observations:                 297   AIC:                             2234.
# Df Residuals:                     288   BIC:                             2267.
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              -64.1673      6.676     -9.611      0.000     -77.308     -51.027
# real_xr           1.048e+06   7.34e+04     14.266      0.000    9.03e+05    1.19e+06
# ca_gdp_korea        -2.4779      0.317     -7.819      0.000      -3.102      -1.854
# ca_gdp_jp            7.9129      0.670     11.804      0.000       6.593       9.232
# gdp_growth_korea     1.6179      0.279      5.795      0.000       1.068       2.167
# gdp_growth_jp       -1.8598      0.310     -6.003      0.000      -2.470      -1.250
# int_rate_diff        6.3370      0.637      9.941      0.000       5.082       7.592
# reserves_to_gdp     -1.5687      0.241     -6.507      0.000      -2.043      -1.094
# reserves_growth      0.2663      0.045      5.958      0.000       0.178       0.354
# ==============================================================================
# Omnibus:                      122.421   Durbin-Watson:                   0.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              702.386
# Skew:                           1.591   Prob(JB):                    3.01e-153
# Kurtosis:                       9.829   Cond. No.                     3.55e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.55e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
